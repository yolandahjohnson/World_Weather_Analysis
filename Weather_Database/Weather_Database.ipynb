# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import citipy module.
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
weather_api_key=""

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(5)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                           "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | chokurdakh
# Processing Record 3 of Set 1 | neka
# Processing Record 4 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | upernavik
# Processing Record 8 of Set 1 | joao pinheiro
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | broome
# Processing Record 11 of Set 1 | nikolskoye
# Processing Record 12 of Set 1 | demirci
# Processing Record 13 of Set 1 | maltahohe
# Processing Record 14 of Set 1 | karratha
# Processing Record 15 of Set 1 | east london
# Processing Record 16 of Set 1 | myitkyina
# Processing Record 17 of Set 1 | tuktoyaktuk
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | skjervoy
# Processing Record 20 of Set 1 | bela
# Processing Record 21 of Set 1 | victoria
# Processing Record 22 of Set 1 | san vicente
# Processing Record 23 of Set 1 | pangnirtung
# Processing Record 24 of Set 1 | hobart
# Processing Record 25 of Set 1 | olinda
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | panjab
# Processing Record 28 of Set 1 | verkhnyaya inta
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | alpena
# Processing Record 31 of Set 1 | katherine
# Processing Record 32 of Set 1 | port said
# Processing Record 33 of Set 1 | namatanai
# Processing Record 34 of Set 1 | esperance
# Processing Record 35 of Set 1 | angoche
# Processing Record 36 of Set 1 | huangcun
# Processing Record 37 of Set 1 | hasaki
# Processing Record 38 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 1 | japura
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | chiang khong
# Processing Record 42 of Set 1 | faanui
# Processing Record 43 of Set 1 | dikson
# Processing Record 44 of Set 1 | adre
# Processing Record 45 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 1 | pevek
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | lorengau
# Processing Record 49 of Set 1 | rawson
# Processing Record 50 of Set 1 | sapele
# Processing Record 1 of Set 2 | nouadhibou
# Processing Record 2 of Set 2 | comodoro rivadavia
# Processing Record 3 of Set 2 | nisia floresta
# Processing Record 4 of Set 2 | pasni
# Processing Record 5 of Set 2 | fort nelson
# Processing Record 6 of Set 2 | mount isa
# Processing Record 7 of Set 2 | longyearbyen
# Processing Record 8 of Set 2 | altamira
# Processing Record 9 of Set 2 | rikitea
# Processing Record 10 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 2 | slave lake
# Processing Record 12 of Set 2 | juegang
# Processing Record 13 of Set 2 | kapaa
# Processing Record 14 of Set 2 | windhoek
# Processing Record 15 of Set 2 | alenquer
# Processing Record 16 of Set 2 | lebu
# Processing Record 17 of Set 2 | kruisfontein
# Processing Record 18 of Set 2 | srednekolymsk
# Processing Record 19 of Set 2 | puerto ayora
# Processing Record 20 of Set 2 | flinders
# Processing Record 21 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 2 | port elizabeth
# Processing Record 23 of Set 2 | punta arenas
# Processing Record 24 of Set 2 | kandrian
# Processing Record 25 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 2 | tiksi
# Processing Record 27 of Set 2 | tasiilaq
# Processing Record 28 of Set 2 | hilo
# Processing Record 29 of Set 2 | fairbanks
# Processing Record 30 of Set 2 | mahebourg
# Processing Record 31 of Set 2 | hermanus
# Processing Record 32 of Set 2 | marshall
# Processing Record 33 of Set 2 | kaitangata
# Processing Record 34 of Set 2 | naze
# Processing Record 35 of Set 2 | sunland park
# Processing Record 36 of Set 2 | klaksvik
# Processing Record 37 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 2 | iqaluit
# Processing Record 39 of Set 2 | sari
# Processing Record 40 of Set 2 | sumenep
# Processing Record 41 of Set 2 | bambous virieux
# Processing Record 42 of Set 2 | hamilton
# Processing Record 43 of Set 2 | port angeles
# Processing Record 44 of Set 2 | qaanaaq
# Processing Record 45 of Set 2 | cayenne
# Processing Record 46 of Set 2 | avarua
# Processing Record 47 of Set 2 | vaini
# Processing Record 48 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 2 | sao filipe
# Processing Record 50 of Set 2 | baruun-urt
# Processing Record 1 of Set 3 | gewane
# Processing Record 2 of Set 3 | mattru
# Processing Record 3 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 4 of Set 3 | ponta do sol
# Processing Record 5 of Set 3 | verkhniy mamon
# Processing Record 6 of Set 3 | ostrovnoy
# Processing Record 7 of Set 3 | arraial do cabo
# Processing Record 8 of Set 3 | souillac
# Processing Record 9 of Set 3 | zelenikovo
# Processing Record 10 of Set 3 | bambanglipuro
# Processing Record 11 of Set 3 | port hedland
# Processing Record 12 of Set 3 | yar-sale
# Processing Record 13 of Set 3 | la plata
# Processing Record 14 of Set 3 | atuona
# Processing Record 15 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 3 | torata
# Processing Record 17 of Set 3 | kyshtovka
# Processing Record 18 of Set 3 | nanortalik
# Processing Record 19 of Set 3 | ilulissat
# Processing Record 20 of Set 3 | georgetown
# Processing Record 21 of Set 3 | saint-philippe
# Processing Record 22 of Set 3 | carnarvon
# Processing Record 23 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 3 | butaritari
# Processing Record 25 of Set 3 | luanda
# Processing Record 26 of Set 3 | antropovo
# Processing Record 27 of Set 3 | esna
# Processing Record 28 of Set 3 | manaira
# Processing Record 29 of Set 3 | pimentel
# Processing Record 30 of Set 3 | cidreira
# Processing Record 31 of Set 3 | mataura
# Processing Record 32 of Set 3 | cuamba
# Processing Record 33 of Set 3 | talara
# Processing Record 34 of Set 3 | kodiak
# Processing Record 35 of Set 3 | arrifes
# Processing Record 36 of Set 3 | saldanha
# Processing Record 37 of Set 3 | mantua
# Processing Record 38 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 3 | kargil
# Processing Record 40 of Set 3 | yamethin
# Processing Record 41 of Set 3 | river falls
# Processing Record 42 of Set 3 | hanko
# Processing Record 43 of Set 3 | okato
# Processing Record 44 of Set 3 | labuhan
# Processing Record 45 of Set 3 | jalu
# Processing Record 46 of Set 3 | shcholkine
# City not found. Skipping...
# Processing Record 47 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 48 of Set 3 | hithadhoo
# Processing Record 49 of Set 3 | mrakovo
# Processing Record 50 of Set 3 | ambilobe
# Processing Record 1 of Set 4 | bandarbeyla
# Processing Record 2 of Set 4 | te anau
# Processing Record 3 of Set 4 | lagoa
# Processing Record 4 of Set 4 | bengkulu
# Processing Record 5 of Set 4 | castro
# Processing Record 6 of Set 4 | beloha
# Processing Record 7 of Set 4 | valle de allende
# Processing Record 8 of Set 4 | cape town
# Processing Record 9 of Set 4 | vila franca do campo
# Processing Record 10 of Set 4 | banda aceh
# Processing Record 11 of Set 4 | norman wells
# Processing Record 12 of Set 4 | mar del plata
# Processing Record 13 of Set 4 | torbay
# Processing Record 14 of Set 4 | springfield
# Processing Record 15 of Set 4 | yulara
# Processing Record 16 of Set 4 | payo
# Processing Record 17 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 18 of Set 4 | saint-pierre
# Processing Record 19 of Set 4 | axim
# Processing Record 20 of Set 4 | korla
# Processing Record 21 of Set 4 | danielskuil
# Processing Record 22 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 4 | goba
# Processing Record 24 of Set 4 | novonukutskiy
# Processing Record 25 of Set 4 | jacksonville
# Processing Record 26 of Set 4 | caravelas
# Processing Record 27 of Set 4 | nelson bay
# Processing Record 28 of Set 4 | port blair
# Processing Record 29 of Set 4 | aklavik
# Processing Record 30 of Set 4 | touros
# Processing Record 31 of Set 4 | palu
# Processing Record 32 of Set 4 | batagay-alyta
# Processing Record 33 of Set 4 | bethel
# Processing Record 34 of Set 4 | ambovombe
# Processing Record 35 of Set 4 | clyde river
# Processing Record 36 of Set 4 | nanchang
# Processing Record 37 of Set 4 | kuytun
# Processing Record 38 of Set 4 | san carlos
# Processing Record 39 of Set 4 | cabo san lucas
# Processing Record 40 of Set 4 | cascais
# Processing Record 41 of Set 4 | new norfolk
# Processing Record 42 of Set 4 | tlanchinol
# Processing Record 43 of Set 4 | sorland
# Processing Record 44 of Set 4 | kaabong
# Processing Record 45 of Set 4 | avrille
# Processing Record 46 of Set 4 | mareeba
# Processing Record 47 of Set 4 | port hawkesbury
# Processing Record 48 of Set 4 | balikpapan
# Processing Record 49 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 50 of Set 4 | navirai
# Processing Record 1 of Set 5 | saint george
# Processing Record 2 of Set 5 | jamestown
# Processing Record 3 of Set 5 | poum
# Processing Record 4 of Set 5 | cherskiy
# Processing Record 5 of Set 5 | barrow
# Processing Record 6 of Set 5 | armacao dos buzios
# City not found. Skipping...
# Processing Record 7 of Set 5 | tombouctou
# Processing Record 8 of Set 5 | katsuura
# Processing Record 9 of Set 5 | plettenberg bay
# Processing Record 10 of Set 5 | ocampo
# Processing Record 11 of Set 5 | luderitz
# Processing Record 12 of Set 5 | college
# Processing Record 13 of Set 5 | muros
# Processing Record 14 of Set 5 | maniitsoq
# Processing Record 15 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 5 | batemans bay
# Processing Record 17 of Set 5 | dudinka
# Processing Record 18 of Set 5 | aquiraz
# Processing Record 19 of Set 5 | taunggyi
# Processing Record 20 of Set 5 | udachnyy
# Processing Record 21 of Set 5 | mount pleasant
# Processing Record 22 of Set 5 | salina cruz
# Processing Record 23 of Set 5 | severo-kurilsk
# Processing Record 24 of Set 5 | mafinga
# Processing Record 25 of Set 5 | vestmannaeyjar
# Processing Record 26 of Set 5 | balkanabat
# Processing Record 27 of Set 5 | kavieng
# Processing Record 28 of Set 5 | eskasem
# City not found. Skipping...
# Processing Record 29 of Set 5 | itoman
# Processing Record 30 of Set 5 | sao jose da coroa grande
# Processing Record 31 of Set 5 | mana
# Processing Record 32 of Set 5 | saskylakh
# Processing Record 33 of Set 5 | airai
# Processing Record 34 of Set 5 | high level
# Processing Record 35 of Set 5 | okhotsk
# Processing Record 36 of Set 5 | gra liyia
# Processing Record 37 of Set 5 | flin flon
# Processing Record 38 of Set 5 | dianopolis
# City not found. Skipping...
# Processing Record 39 of Set 5 | lasa
# Processing Record 40 of Set 5 | kupang
# Processing Record 41 of Set 5 | thompson
# Processing Record 42 of Set 5 | abiramam
# Processing Record 43 of Set 5 | eydhafushi
# Processing Record 44 of Set 5 | inhambane
# Processing Record 45 of Set 5 | fort saint james
# Processing Record 46 of Set 5 | mehamn
# Processing Record 47 of Set 5 | cheyenne
# Processing Record 48 of Set 5 | tarakan
# Processing Record 49 of Set 5 | sibolga
# Processing Record 50 of Set 5 | tuam
# Processing Record 1 of Set 6 | makasar
# Processing Record 2 of Set 6 | cairns
# Processing Record 3 of Set 6 | turukhansk
# Processing Record 4 of Set 6 | kearney
# Processing Record 5 of Set 6 | roebourne
# Processing Record 6 of Set 6 | teknaf
# Processing Record 7 of Set 6 | buluang
# Processing Record 8 of Set 6 | mackay
# Processing Record 9 of Set 6 | milkovo
# Processing Record 10 of Set 6 | mirabad
# Processing Record 11 of Set 6 | ambanja
# Processing Record 12 of Set 6 | shache
# Processing Record 13 of Set 6 | umm jarr
# City not found. Skipping...
# Processing Record 14 of Set 6 | taoudenni
# Processing Record 15 of Set 6 | nome
# Processing Record 16 of Set 6 | arlit
# Processing Record 17 of Set 6 | havelock
# Processing Record 18 of Set 6 | funadhoo
# Processing Record 19 of Set 6 | lompoc
# Processing Record 20 of Set 6 | chuguyevka
# Processing Record 21 of Set 6 | buala
# Processing Record 22 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 6 | fortuna
# Processing Record 24 of Set 6 | virginia beach
# Processing Record 25 of Set 6 | natal
# Processing Record 26 of Set 6 | lhuntshi
# City not found. Skipping...
# Processing Record 27 of Set 6 | bakel
# Processing Record 28 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 29 of Set 6 | puerto escondido
# Processing Record 30 of Set 6 | sorong
# Processing Record 31 of Set 6 | ostersund
# Processing Record 32 of Set 6 | ryazan
# Processing Record 33 of Set 6 | alburikent
# Processing Record 34 of Set 6 | evensk
# Processing Record 35 of Set 6 | podporozhye
# Processing Record 36 of Set 6 | leningradskiy
# Processing Record 37 of Set 6 | chuy
# Processing Record 38 of Set 6 | greeneville
# Processing Record 39 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 6 | provideniya
# Processing Record 41 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 42 of Set 6 | whitehaven
# Processing Record 43 of Set 6 | coihaique
# Processing Record 44 of Set 6 | bajil
# Processing Record 45 of Set 6 | pomabamba
# Processing Record 46 of Set 6 | san luis
# Processing Record 47 of Set 6 | muscat
# Processing Record 48 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 6 | mogadishu
# Processing Record 50 of Set 6 | sitka
# Processing Record 1 of Set 7 | yarensk
# Processing Record 2 of Set 7 | doha
# Processing Record 3 of Set 7 | champerico
# Processing Record 4 of Set 7 | huilong
# Processing Record 5 of Set 7 | show low
# Processing Record 6 of Set 7 | san patricio
# Processing Record 7 of Set 7 | fare
# Processing Record 8 of Set 7 | lakes entrance
# Processing Record 9 of Set 7 | marsa matruh
# Processing Record 10 of Set 7 | bireun
# Processing Record 11 of Set 7 | alugan
# Processing Record 12 of Set 7 | haines junction
# Processing Record 13 of Set 7 | bathsheba
# Processing Record 14 of Set 7 | russell
# Processing Record 15 of Set 7 | paamiut
# Processing Record 16 of Set 7 | botro
# Processing Record 17 of Set 7 | husavik
# Processing Record 18 of Set 7 | inirida
# Processing Record 19 of Set 7 | post falls
# Processing Record 20 of Set 7 | amot
# Processing Record 21 of Set 7 | dingle
# Processing Record 22 of Set 7 | sao joao de pirabas
# Processing Record 23 of Set 7 | nakhon thai
# Processing Record 24 of Set 7 | marawi
# Processing Record 25 of Set 7 | ferme-neuve
# Processing Record 26 of Set 7 | vaitape
# Processing Record 27 of Set 7 | tambopata
# Processing Record 28 of Set 7 | kungurtug
# Processing Record 29 of Set 7 | ugoofaaru
# Processing Record 30 of Set 7 | ribeira grande
# Processing Record 31 of Set 7 | sarakhs
# Processing Record 32 of Set 7 | nador
# Processing Record 33 of Set 7 | ukiah
# Processing Record 34 of Set 7 | kedainiai
# Processing Record 35 of Set 7 | evanston
# Processing Record 36 of Set 7 | kadrina
# Processing Record 37 of Set 7 | akdepe
# Processing Record 38 of Set 7 | lethem
# Processing Record 39 of Set 7 | bima
# Processing Record 40 of Set 7 | merthyr tydfil
# Processing Record 41 of Set 7 | cartagena
# Processing Record 42 of Set 7 | kazerun
# Processing Record 43 of Set 7 | shambu
# Processing Record 44 of Set 7 | paranapanema
# Processing Record 45 of Set 7 | mosquera
# Processing Record 46 of Set 7 | golyshmanovo
# Processing Record 47 of Set 7 | saint-louis
# Processing Record 48 of Set 7 | havre-saint-pierre
# Processing Record 49 of Set 7 | north bend
# Processing Record 50 of Set 7 | port hardy
# Processing Record 1 of Set 8 | muroto
# Processing Record 2 of Set 8 | saint-joseph
# Processing Record 3 of Set 8 | zhaotong
# Processing Record 4 of Set 8 | trairi
# Processing Record 5 of Set 8 | pocone
# Processing Record 6 of Set 8 | denpasar
# Processing Record 7 of Set 8 | avera
# Processing Record 8 of Set 8 | half moon bay
# Processing Record 9 of Set 8 | tunggol
# Processing Record 10 of Set 8 | samatau
# City not found. Skipping...
# Processing Record 11 of Set 8 | yaqui
# Processing Record 12 of Set 8 | comarapa
# Processing Record 13 of Set 8 | porto novo
# Processing Record 14 of Set 8 | acapulco
# Processing Record 15 of Set 8 | byron bay
# Processing Record 16 of Set 8 | codrington
# Processing Record 17 of Set 8 | cabra
# Processing Record 18 of Set 8 | vardo
# Processing Record 19 of Set 8 | gangakher
# Processing Record 20 of Set 8 | celestun
# Processing Record 21 of Set 8 | tendukheda
# Processing Record 22 of Set 8 | paragominas
# Processing Record 23 of Set 8 | padang
# Processing Record 24 of Set 8 | itarema
# Processing Record 25 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 8 | rocha
# Processing Record 27 of Set 8 | tamale
# Processing Record 28 of Set 8 | richards bay
# Processing Record 29 of Set 8 | seoul
# Processing Record 30 of Set 8 | kutum
# Processing Record 31 of Set 8 | barkot
# Processing Record 32 of Set 8 | svetlaya
# Processing Record 33 of Set 8 | vestbygda
# City not found. Skipping...
# Processing Record 34 of Set 8 | gap
# Processing Record 35 of Set 8 | la ronge
# Processing Record 36 of Set 8 | rabo de peixe
# Processing Record 37 of Set 8 | trogir
# Processing Record 38 of Set 8 | marfino
# Processing Record 39 of Set 8 | faya
# Processing Record 40 of Set 8 | bereda
# Processing Record 41 of Set 8 | benjamin constant
# Processing Record 42 of Set 8 | muisne
# Processing Record 43 of Set 8 | pemangkat
# Processing Record 44 of Set 8 | rantepao
# Processing Record 45 of Set 8 | youghal
# Processing Record 46 of Set 8 | apache junction
# Processing Record 47 of Set 8 | vanavara
# Processing Record 48 of Set 8 | dunedin
# Processing Record 49 of Set 8 | qaqortoq
# Processing Record 50 of Set 8 | dauphin
# Processing Record 1 of Set 9 | swan river
# Processing Record 2 of Set 9 | jipijapa
# Processing Record 3 of Set 9 | nabire
# Processing Record 4 of Set 9 | harper
# Processing Record 5 of Set 9 | tuatapere
# Processing Record 6 of Set 9 | aswan
# Processing Record 7 of Set 9 | pacific grove
# Processing Record 8 of Set 9 | sande
# Processing Record 9 of Set 9 | shatsk
# Processing Record 10 of Set 9 | sechura
# Processing Record 11 of Set 9 | puri
# Processing Record 12 of Set 9 | jijiang
# Processing Record 13 of Set 9 | ancud
# Processing Record 14 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 15 of Set 9 | kalmunai
# Processing Record 16 of Set 9 | lata
# Processing Record 17 of Set 9 | newport
# Processing Record 18 of Set 9 | mananjary
# Processing Record 19 of Set 9 | changji
# Processing Record 20 of Set 9 | kirakira
# Processing Record 21 of Set 9 | smoky lake
# Processing Record 22 of Set 9 | adrar
# Processing Record 23 of Set 9 | modakeke
# Processing Record 24 of Set 9 | bairiki
# Processing Record 25 of Set 9 | guerrero negro
# Processing Record 26 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 27 of Set 9 | auch
# Processing Record 28 of Set 9 | ahipara
# Processing Record 29 of Set 9 | hammerfest
# Processing Record 30 of Set 9 | gigmoto
# Processing Record 31 of Set 9 | cap-aux-meules
# Processing Record 32 of Set 9 | tuy hoa
# Processing Record 33 of Set 9 | abha
# Processing Record 34 of Set 9 | khailar
# Processing Record 35 of Set 9 | kahului
# Processing Record 36 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 9 | camacha
# Processing Record 38 of Set 9 | khandyga
# Processing Record 39 of Set 9 | linqiong
# Processing Record 40 of Set 9 | thinadhoo
# Processing Record 41 of Set 9 | adancata
# Processing Record 42 of Set 9 | atherton
# Processing Record 43 of Set 9 | pimenta bueno
# Processing Record 44 of Set 9 | saint-augustin
# Processing Record 45 of Set 9 | fecamp
# Processing Record 46 of Set 9 | suzu
# City not found. Skipping...
# Processing Record 47 of Set 9 | coquimbo
# Processing Record 48 of Set 9 | kalengwa
# Processing Record 49 of Set 9 | manzanillo
# Processing Record 50 of Set 9 | mezen
# Processing Record 1 of Set 10 | grindavik
# Processing Record 2 of Set 10 | dalmeny
# Processing Record 3 of Set 10 | kavaratti
# Processing Record 4 of Set 10 | ornskoldsvik
# Processing Record 5 of Set 10 | samana
# Processing Record 6 of Set 10 | frontera
# Processing Record 7 of Set 10 | jerecuaro
# Processing Record 8 of Set 10 | mokrous
# Processing Record 9 of Set 10 | santa marta
# Processing Record 10 of Set 10 | shubarkuduk
# Processing Record 11 of Set 10 | miraflores
# Processing Record 12 of Set 10 | qasigiannguit
# Processing Record 13 of Set 10 | agropoli
# Processing Record 14 of Set 10 | paarl
# Processing Record 15 of Set 10 | shingu
# Processing Record 16 of Set 10 | san quintin
# Processing Record 17 of Set 10 | launceston
# Processing Record 18 of Set 10 | chaozhou
# Processing Record 19 of Set 10 | nykobing
# City not found. Skipping...
# Processing Record 20 of Set 10 | solnechnyy
# Processing Record 21 of Set 10 | awjilah
# Processing Record 22 of Set 10 | safaqis
# City not found. Skipping...
# Processing Record 23 of Set 10 | bonthe
# Processing Record 24 of Set 10 | williamsburg
# Processing Record 25 of Set 10 | ushtobe
# Processing Record 26 of Set 10 | vao
# Processing Record 27 of Set 10 | la paz
# Processing Record 28 of Set 10 | hobyo
# Processing Record 29 of Set 10 | poletayevo
# Processing Record 30 of Set 10 | talakan
# Processing Record 31 of Set 10 | conchal
# Processing Record 32 of Set 10 | shelburne
# Processing Record 33 of Set 10 | bondo
# Processing Record 34 of Set 10 | asyut
# Processing Record 35 of Set 10 | lilongwe
# Processing Record 36 of Set 10 | sotnikovo
# Processing Record 37 of Set 10 | cabinda
# Processing Record 38 of Set 10 | khatanga
# Processing Record 39 of Set 10 | teluk nibung
# Processing Record 40 of Set 10 | shatrovo
# Processing Record 41 of Set 10 | malegaon
# Processing Record 42 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 43 of Set 10 | constitucion
# Processing Record 44 of Set 10 | tubuala
# Processing Record 45 of Set 10 | neyshabur
# Processing Record 46 of Set 10 | mitchell
# Processing Record 47 of Set 10 | noumea
# Processing Record 48 of Set 10 | paraiso
# Processing Record 49 of Set 10 | pedernales
# Processing Record 50 of Set 10 | booue
# Processing Record 1 of Set 11 | tamiahua
# Processing Record 2 of Set 11 | kourou
# Processing Record 3 of Set 11 | keflavik
# Processing Record 4 of Set 11 | juneau
# Processing Record 5 of Set 11 | tessalit
# Processing Record 6 of Set 11 | butembo
# Processing Record 7 of Set 11 | neiafu
# Processing Record 8 of Set 11 | iquitos
# Processing Record 9 of Set 11 | balad
# Processing Record 10 of Set 11 | tura
# Processing Record 11 of Set 11 | fenoarivo atsinanana
# Processing Record 12 of Set 11 | kermanshah
# Processing Record 13 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 11 | latung
# Processing Record 15 of Set 11 | mount gambier
# Processing Record 16 of Set 11 | hambantota
# Processing Record 17 of Set 11 | salina
# Processing Record 18 of Set 11 | dwarka
# Processing Record 19 of Set 11 | bay roberts
# Processing Record 20 of Set 11 | saint anthony
# Processing Record 21 of Set 11 | dalby
# Processing Record 22 of Set 11 | severnyy
# Processing Record 23 of Set 11 | jawhar
# Processing Record 24 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 25 of Set 11 | ruangwa
# Processing Record 26 of Set 11 | amos
# Processing Record 27 of Set 11 | ewa beach
# Processing Record 28 of Set 11 | santa cruz
# Processing Record 29 of Set 11 | cururupu
# Processing Record 30 of Set 11 | yumen
# Processing Record 31 of Set 11 | torres
# Processing Record 32 of Set 11 | inta
# Processing Record 33 of Set 11 | ascension
# Processing Record 34 of Set 11 | ganzhou
# Processing Record 35 of Set 11 | arequipa
# Processing Record 36 of Set 11 | bowen
# Processing Record 37 of Set 11 | pauini
# Processing Record 38 of Set 11 | riyadh
# Processing Record 39 of Set 11 | suntar
# Processing Record 40 of Set 11 | biskamzha
# Processing Record 41 of Set 11 | alghero
# Processing Record 42 of Set 11 | togur
# Processing Record 43 of Set 11 | barcelona
# Processing Record 44 of Set 11 | saint-michel-des-saints
# Processing Record 45 of Set 11 | normandin
# Processing Record 46 of Set 11 | nebbi
# Processing Record 47 of Set 11 | safaga
# Processing Record 48 of Set 11 | mecca
# Processing Record 49 of Set 11 | garden city
# Processing Record 50 of Set 11 | oum hadjer
# Processing Record 1 of Set 12 | kathu
# Processing Record 2 of Set 12 | aitape
# Processing Record 3 of Set 12 | kumluca
# Processing Record 4 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 5 of Set 12 | dolores
# Processing Record 6 of Set 12 | mocuba
# Processing Record 7 of Set 12 | russellville
# Processing Record 8 of Set 12 | logan lake
# Processing Record 9 of Set 12 | pisco
# Processing Record 10 of Set 12 | eureka
# Processing Record 11 of Set 12 | goderich
# Processing Record 12 of Set 12 | batie
# Processing Record 13 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 14 of Set 12 | asfi
# Processing Record 15 of Set 12 | belmonte
# Processing Record 16 of Set 12 | talnakh
# Processing Record 17 of Set 12 | gizo
# Processing Record 18 of Set 12 | salalah
# Processing Record 19 of Set 12 | maceio
# Processing Record 20 of Set 12 | pocoes
# Processing Record 21 of Set 12 | vicosa do ceara
# Processing Record 22 of Set 12 | salinopolis
# Processing Record 23 of Set 12 | beringovskiy
# Processing Record 24 of Set 12 | kozhva
# Processing Record 25 of Set 12 | port lincoln
# Processing Record 26 of Set 12 | livingston
# Processing Record 27 of Set 12 | jumla
# Processing Record 28 of Set 12 | vodnyy
# Processing Record 29 of Set 12 | ihosy
# Processing Record 30 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 31 of Set 12 | fort morgan
# Processing Record 32 of Set 12 | doka
# Processing Record 33 of Set 12 | ratnagiri
# Processing Record 34 of Set 12 | matsanga
# City not found. Skipping...
# Processing Record 35 of Set 12 | halifax
# Processing Record 36 of Set 12 | bojonegoro
# Processing Record 37 of Set 12 | berlevag
# Processing Record 38 of Set 12 | redding
# Processing Record 39 of Set 12 | ibra
# Processing Record 40 of Set 12 | muriti
# Processing Record 41 of Set 12 | lang son
# Processing Record 42 of Set 12 | kindersley
# Processing Record 43 of Set 12 | ozernovskiy
# Processing Record 44 of Set 12 | san joaquin
# Processing Record 45 of Set 12 | nioro
# Processing Record 46 of Set 12 | morehead
# Processing Record 47 of Set 12 | terrace
# Processing Record 48 of Set 12 | nouakchott
# Processing Record 49 of Set 12 | ginir
# Processing Record 50 of Set 12 | olafsvik
# Processing Record 1 of Set 13 | thunder bay
# Processing Record 2 of Set 13 | acheng
# Processing Record 3 of Set 13 | toro
# Processing Record 4 of Set 13 | verkhnevilyuysk
# Processing Record 5 of Set 13 | jishou
# Processing Record 6 of Set 13 | bage
# Processing Record 7 of Set 13 | zhuanghe
# Processing Record 8 of Set 13 | lavrentiya
# Processing Record 9 of Set 13 | ranong
# Processing Record 10 of Set 13 | kodinsk
# Processing Record 11 of Set 13 | manaus
# Processing Record 12 of Set 13 | scarborough
# Processing Record 13 of Set 13 | litovko
# Processing Record 14 of Set 13 | pitimbu
# Processing Record 15 of Set 13 | poronaysk
# Processing Record 16 of Set 13 | brae
# Processing Record 17 of Set 13 | gallup
# Processing Record 18 of Set 13 | shinpokh
# Processing Record 19 of Set 13 | aki
# Processing Record 20 of Set 13 | liwale
# Processing Record 21 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 22 of Set 13 | perez
# Processing Record 23 of Set 13 | mackenzie
# Processing Record 24 of Set 13 | bull savanna
# Processing Record 25 of Set 13 | ixtapa
# Processing Record 26 of Set 13 | tevaitoa
# Processing Record 27 of Set 13 | kayes
# Processing Record 28 of Set 13 | aranos
# Processing Record 29 of Set 13 | dien bien
# City not found. Skipping...
# Processing Record 30 of Set 13 | teguldet
# Processing Record 31 of Set 13 | moura
# Processing Record 32 of Set 13 | nantucket
# Processing Record 33 of Set 13 | hastings
# Processing Record 34 of Set 13 | darasun
# Processing Record 35 of Set 13 | honggang
# Processing Record 36 of Set 13 | chernyshevskiy
# Processing Record 37 of Set 13 | dawei
# Processing Record 38 of Set 13 | langsa
# Processing Record 39 of Set 13 | tarpon springs
# Processing Record 40 of Set 13 | geraldton
# Processing Record 41 of Set 13 | arvin
# Processing Record 42 of Set 13 | sierra vista
# Processing Record 43 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 44 of Set 13 | yelizovo
# Processing Record 45 of Set 13 | kapoeta
# Processing Record 46 of Set 13 | aykhal
# Processing Record 47 of Set 13 | toungoo
# City not found. Skipping...
# Processing Record 48 of Set 13 | verkh-usugli
# Processing Record 49 of Set 13 | bara
# Processing Record 50 of Set 13 | phibun mangsahan
# Processing Record 1 of Set 14 | taltal
# Processing Record 2 of Set 14 | mananara
# Processing Record 3 of Set 14 | mitu
# Processing Record 4 of Set 14 | taiyuan
# Processing Record 5 of Set 14 | boljarovo
# City not found. Skipping...
# Processing Record 6 of Set 14 | male
# Processing Record 7 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 8 of Set 14 | zhigansk
# Processing Record 9 of Set 14 | lowicz
# Processing Record 10 of Set 14 | south lake tahoe
# Processing Record 11 of Set 14 | camocim
# Processing Record 12 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 13 of Set 14 | portarlington
# Processing Record 14 of Set 14 | sangueya
# Processing Record 15 of Set 14 | maracaibo
# Processing Record 16 of Set 14 | puerto leguizamo
# Processing Record 17 of Set 14 | buchanan
# Processing Record 18 of Set 14 | udhampur
# Processing Record 19 of Set 14 | sao miguel
# Processing Record 20 of Set 14 | tahoua
# Processing Record 21 of Set 14 | san cristobal
# Processing Record 22 of Set 14 | ust-koksa
# Processing Record 23 of Set 14 | dangriga
# Processing Record 24 of Set 14 | san ignacio
# Processing Record 25 of Set 14 | vanimo
# Processing Record 26 of Set 14 | holme
# Processing Record 27 of Set 14 | hami
# Processing Record 28 of Set 14 | tanjong sepat
# City not found. Skipping...
# Processing Record 29 of Set 14 | narsaq
# Processing Record 30 of Set 14 | yasnogorsk
# Processing Record 31 of Set 14 | solwezi
# Processing Record 32 of Set 14 | jackson
# Processing Record 33 of Set 14 | praya
# Processing Record 34 of Set 14 | navahrudak
# Processing Record 35 of Set 14 | guanay
# Processing Record 36 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 37 of Set 14 | marsh harbour
# Processing Record 38 of Set 14 | kudahuvadhoo
# Processing Record 39 of Set 14 | bawku
# Processing Record 40 of Set 14 | moyale
# Processing Record 41 of Set 14 | samarai
# Processing Record 42 of Set 14 | katsiveli
# City not found. Skipping...
# Processing Record 43 of Set 14 | omutinskoye
# City not found. Skipping...
# Processing Record 44 of Set 14 | port augusta
# Processing Record 45 of Set 14 | sinnamary
# Processing Record 46 of Set 14 | wajir
# Processing Record 47 of Set 14 | lao cai
# Processing Record 48 of Set 14 | krasnik
# Processing Record 49 of Set 14 | sangar
# Processing Record 50 of Set 14 | chapais
# Processing Record 1 of Set 15 | piryion
# City not found. Skipping...
# Processing Record 2 of Set 15 | kholmogory
# Processing Record 3 of Set 15 | montrose
# Processing Record 4 of Set 15 | saint-paul
# Processing Record 5 of Set 15 | othonoi
# City not found. Skipping...
# Processing Record 6 of Set 15 | guanare
# Processing Record 7 of Set 15 | hualmay
# Processing Record 8 of Set 15 | sur
# Processing Record 9 of Set 15 | waingapu
# Processing Record 10 of Set 15 | ventspils
# Processing Record 11 of Set 15 | abdanan
# Processing Record 12 of Set 15 | tiznit
# Processing Record 13 of Set 15 | kawalu
# Processing Record 14 of Set 15 | smithers
# Processing Record 15 of Set 15 | kieta
# Processing Record 16 of Set 15 | san juan de los morros
# Processing Record 17 of Set 15 | chistoye
# Processing Record 18 of Set 15 | lithakia
# Processing Record 19 of Set 15 | troitskoye
# Processing Record 20 of Set 15 | tilichiki
# Processing Record 21 of Set 15 | chara
# Processing Record 22 of Set 15 | ketchikan
# Processing Record 23 of Set 15 | cherepovets
# Processing Record 24 of Set 15 | suhbaatar
# Processing Record 25 of Set 15 | alta floresta
# Processing Record 26 of Set 15 | reynosa
# Processing Record 27 of Set 15 | saint-leu
# Processing Record 28 of Set 15 | roald
# Processing Record 29 of Set 15 | cay
# Processing Record 30 of Set 15 | usinsk
# Processing Record 31 of Set 15 | anloga
# Processing Record 32 of Set 15 | jutai
# Processing Record 33 of Set 15 | oktyabrskoye
# Processing Record 34 of Set 15 | sao joao da barra
# Processing Record 35 of Set 15 | shunyi
# Processing Record 36 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 15 | mariental
# Processing Record 38 of Set 15 | brigantine
# Processing Record 39 of Set 15 | gaoua
# Processing Record 40 of Set 15 | chulman
# Processing Record 41 of Set 15 | lovington
# Processing Record 42 of Set 15 | garowe
# Processing Record 43 of Set 15 | paso blanco
# Processing Record 44 of Set 15 | crotone
# Processing Record 45 of Set 15 | milan
# Processing Record 46 of Set 15 | isangel
# Processing Record 47 of Set 15 | zlynka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Yellowknife      CA  62.4560 -114.3525     39.72        81         100
# 1     Chokurdakh      RU  70.6333  147.9167     21.52        83         100
# 2           Neka      IR  36.6508   53.2990     58.14        85           3
# 3      Busselton      AU -33.6500  115.3333     56.48        53           0
# 4      Upernavik      GL  72.7868  -56.1549      3.90        95           7
# 5  Joao Pinheiro      BR -17.7425  -46.1725     72.19        66          98
# 6        Ushuaia      AR -54.8000  -68.3000     38.86        75           0
# 7         Broome      US  42.2506  -75.8330     55.85        92         100
# 8     Nikolskoye      RU  59.7035   30.7861     37.29        70          87
# 9        Demirci      TR  39.0461   28.6589     41.27        79          49
#
#    Wind Speed Current Description
# 0       11.50          light rain
# 1        4.27     overcast clouds
# 2        2.84           clear sky
# 3       16.26           clear sky
# 4        6.46           clear sky
# 5        4.65     overcast clouds
# 6        5.75           clear sky
# 7        8.05     overcast clouds
# 8        6.29     overcast clouds
# 9        5.37    scattered clouds

# %%
# Export data frame as CSV
output_data_file = 'WeatherPy_Database.csv'
city_data_df.to_csv(output_data_file, index_label="City_ID")
