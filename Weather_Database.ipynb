# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import citipy module.
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(5)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                           "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | san quintin
# Processing Record 2 of Set 1 | mareeba
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | ostersund
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | tasiilaq
# Processing Record 7 of Set 1 | dikson
# Processing Record 8 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | hohhot
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | vao
# Processing Record 13 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 1 | harrison
# Processing Record 15 of Set 1 | padang
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | vadlapudi
# Processing Record 18 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 1 | ulety
# Processing Record 20 of Set 1 | luderitz
# Processing Record 21 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 1 | bongandanga
# Processing Record 23 of Set 1 | krasnyy yar
# Processing Record 24 of Set 1 | korla
# Processing Record 25 of Set 1 | guerrero negro
# Processing Record 26 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 1 | butaritari
# Processing Record 28 of Set 1 | fukue
# Processing Record 29 of Set 1 | linjiang
# Processing Record 30 of Set 1 | nizhniy baskunchak
# Processing Record 31 of Set 1 | kemijarvi
# Processing Record 32 of Set 1 | cepelare
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | parksepa
# Processing Record 37 of Set 1 | bundi
# Processing Record 38 of Set 1 | dve mogili
# Processing Record 39 of Set 1 | bengkulu
# Processing Record 40 of Set 1 | ponta do sol
# Processing Record 41 of Set 1 | vestmannaeyjar
# Processing Record 42 of Set 1 | hami
# Processing Record 43 of Set 1 | nanzhang
# Processing Record 44 of Set 1 | okato
# Processing Record 45 of Set 1 | tuktoyaktuk
# Processing Record 46 of Set 1 | carnarvon
# Processing Record 47 of Set 1 | leninsk
# Processing Record 48 of Set 1 | balikpapan
# Processing Record 49 of Set 1 | raymondville
# Processing Record 50 of Set 1 | muravlenko
# Processing Record 1 of Set 2 | georgetown
# Processing Record 2 of Set 2 | azovo
# Processing Record 3 of Set 2 | barrow
# Processing Record 4 of Set 2 | srandakan
# Processing Record 5 of Set 2 | hermanus
# Processing Record 6 of Set 2 | bredasdorp
# Processing Record 7 of Set 2 | new norfolk
# Processing Record 8 of Set 2 | tari
# Processing Record 9 of Set 2 | kaitangata
# Processing Record 10 of Set 2 | kalamakion
# City not found. Skipping...
# Processing Record 11 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 2 | norman wells
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | lisala
# Processing Record 15 of Set 2 | cherskiy
# Processing Record 16 of Set 2 | xunchang
# Processing Record 17 of Set 2 | samarai
# Processing Record 18 of Set 2 | jamestown
# Processing Record 19 of Set 2 | leningradskiy
# Processing Record 20 of Set 2 | viedma
# Processing Record 21 of Set 2 | pevek
# Processing Record 22 of Set 2 | punta arenas
# Processing Record 23 of Set 2 | bambous virieux
# Processing Record 24 of Set 2 | san benito
# Processing Record 25 of Set 2 | taltal
# Processing Record 26 of Set 2 | xining
# Processing Record 27 of Set 2 | awbari
# Processing Record 28 of Set 2 | airai
# Processing Record 29 of Set 2 | albany
# Processing Record 30 of Set 2 | puerto ayora
# Processing Record 31 of Set 2 | qaanaaq
# Processing Record 32 of Set 2 | concordia
# Processing Record 33 of Set 2 | arman
# Processing Record 34 of Set 2 | chuy
# Processing Record 35 of Set 2 | vigrestad
# Processing Record 36 of Set 2 | sosva
# Processing Record 37 of Set 2 | suntar
# Processing Record 38 of Set 2 | samana
# Processing Record 39 of Set 2 | east london
# Processing Record 40 of Set 2 | thompson
# Processing Record 41 of Set 2 | richards bay
# Processing Record 42 of Set 2 | busselton
# Processing Record 43 of Set 2 | lingyuan
# Processing Record 44 of Set 2 | hilo
# Processing Record 45 of Set 2 | chokurdakh
# Processing Record 46 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 2 | vostok
# Processing Record 48 of Set 2 | sitka
# Processing Record 49 of Set 2 | balezino
# Processing Record 50 of Set 2 | zhanaozen
# Processing Record 1 of Set 3 | vila velha
# Processing Record 2 of Set 3 | souillac
# Processing Record 3 of Set 3 | namatanai
# Processing Record 4 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 3 | zemio
# Processing Record 6 of Set 3 | half moon bay
# Processing Record 7 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 3 | mar del plata
# Processing Record 9 of Set 3 | bull savanna
# Processing Record 10 of Set 3 | kapit
# Processing Record 11 of Set 3 | ribeira grande
# Processing Record 12 of Set 3 | berlevag
# Processing Record 13 of Set 3 | constitucion
# Processing Record 14 of Set 3 | bluff
# Processing Record 15 of Set 3 | jamsa
# Processing Record 16 of Set 3 | hithadhoo
# Processing Record 17 of Set 3 | khatanga
# Processing Record 18 of Set 3 | saint-leu
# Processing Record 19 of Set 3 | kavieng
# Processing Record 20 of Set 3 | port alfred
# Processing Record 21 of Set 3 | villarrica
# Processing Record 22 of Set 3 | vaini
# Processing Record 23 of Set 3 | lebu
# Processing Record 24 of Set 3 | port blair
# Processing Record 25 of Set 3 | yellowknife
# Processing Record 26 of Set 3 | touros
# Processing Record 27 of Set 3 | danshui
# Processing Record 28 of Set 3 | portland
# Processing Record 29 of Set 3 | plateros
# Processing Record 30 of Set 3 | te anau
# Processing Record 31 of Set 3 | lluta
# Processing Record 32 of Set 3 | mahebourg
# Processing Record 33 of Set 3 | thinadhoo
# Processing Record 34 of Set 3 | saint george
# Processing Record 35 of Set 3 | batagay
# Processing Record 36 of Set 3 | katsuura
# Processing Record 37 of Set 3 | salalah
# Processing Record 38 of Set 3 | haines junction
# Processing Record 39 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 3 | atambua
# Processing Record 41 of Set 3 | anadyr
# Processing Record 42 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 3 | turka
# Processing Record 44 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 45 of Set 3 | tongzi
# Processing Record 46 of Set 3 | north bend
# Processing Record 47 of Set 3 | meadow lake
# Processing Record 48 of Set 3 | urengoy
# Processing Record 49 of Set 3 | broome
# Processing Record 50 of Set 3 | port lincoln
# Processing Record 1 of Set 4 | hamilton
# Processing Record 2 of Set 4 | hervey bay
# Processing Record 3 of Set 4 | vikulovo
# Processing Record 4 of Set 4 | bathsheba
# Processing Record 5 of Set 4 | saint-philippe
# Processing Record 6 of Set 4 | umba
# Processing Record 7 of Set 4 | nanortalik
# Processing Record 8 of Set 4 | khandyga
# Processing Record 9 of Set 4 | vulcan
# Processing Record 10 of Set 4 | codrington
# Processing Record 11 of Set 4 | bushehr
# Processing Record 12 of Set 4 | zielona gora
# Processing Record 13 of Set 4 | qaqortoq
# Processing Record 14 of Set 4 | talcahuano
# Processing Record 15 of Set 4 | young
# Processing Record 16 of Set 4 | bethel
# Processing Record 17 of Set 4 | port hawkesbury
# Processing Record 18 of Set 4 | beian
# Processing Record 19 of Set 4 | alice springs
# Processing Record 20 of Set 4 | rettikhovka
# Processing Record 21 of Set 4 | dingle
# Processing Record 22 of Set 4 | skegness
# Processing Record 23 of Set 4 | geraldton
# Processing Record 24 of Set 4 | santa ana
# Processing Record 25 of Set 4 | namibe
# Processing Record 26 of Set 4 | jardim
# Processing Record 27 of Set 4 | grand gaube
# Processing Record 28 of Set 4 | cidreira
# Processing Record 29 of Set 4 | eureka
# Processing Record 30 of Set 4 | victoria
# Processing Record 31 of Set 4 | pisco
# Processing Record 32 of Set 4 | lancaster
# Processing Record 33 of Set 4 | maluso
# Processing Record 34 of Set 4 | teknaf
# Processing Record 35 of Set 4 | huarmey
# Processing Record 36 of Set 4 | seddon
# Processing Record 37 of Set 4 | olga
# Processing Record 38 of Set 4 | castro
# Processing Record 39 of Set 4 | syamzha
# Processing Record 40 of Set 4 | nhulunbuy
# Processing Record 41 of Set 4 | naze
# Processing Record 42 of Set 4 | gawler
# Processing Record 43 of Set 4 | kota belud
# Processing Record 44 of Set 4 | sindand
# City not found. Skipping...
# Processing Record 45 of Set 4 | strezhevoy
# Processing Record 46 of Set 4 | podosinovets
# Processing Record 47 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 48 of Set 4 | pangnirtung
# Processing Record 49 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 4 | kavaratti
# Processing Record 1 of Set 5 | la rioja
# Processing Record 2 of Set 5 | iqaluit
# Processing Record 3 of Set 5 | tommot
# Processing Record 4 of Set 5 | brownsville
# Processing Record 5 of Set 5 | banda aceh
# Processing Record 6 of Set 5 | klaksvik
# Processing Record 7 of Set 5 | neuquen
# Processing Record 8 of Set 5 | nishihara
# Processing Record 9 of Set 5 | apan
# Processing Record 10 of Set 5 | whitehorse
# Processing Record 11 of Set 5 | kununurra
# Processing Record 12 of Set 5 | gaur
# Processing Record 13 of Set 5 | sao miguel do araguaia
# Processing Record 14 of Set 5 | sao filipe
# Processing Record 15 of Set 5 | hobyo
# Processing Record 16 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 5 | upernavik
# Processing Record 18 of Set 5 | caravelas
# Processing Record 19 of Set 5 | arlit
# Processing Record 20 of Set 5 | saint-georges
# Processing Record 21 of Set 5 | severo-kurilsk
# Processing Record 22 of Set 5 | burica
# City not found. Skipping...
# Processing Record 23 of Set 5 | shenjiamen
# Processing Record 24 of Set 5 | nome
# Processing Record 25 of Set 5 | dera bugti
# Processing Record 26 of Set 5 | arraial do cabo
# Processing Record 27 of Set 5 | lima
# Processing Record 28 of Set 5 | kutum
# Processing Record 29 of Set 5 | geresk
# City not found. Skipping...
# Processing Record 30 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 5 | katwa
# Processing Record 32 of Set 5 | charleston
# Processing Record 33 of Set 5 | abu jubayhah
# City not found. Skipping...
# Processing Record 34 of Set 5 | narsaq
# Processing Record 35 of Set 5 | maragogi
# Processing Record 36 of Set 5 | kysyl-syr
# Processing Record 37 of Set 5 | husavik
# Processing Record 38 of Set 5 | yerbogachen
# Processing Record 39 of Set 5 | cabedelo
# Processing Record 40 of Set 5 | kapaa
# Processing Record 41 of Set 5 | sandhaven
# City not found. Skipping...
# Processing Record 42 of Set 5 | sao mateus do maranhao
# Processing Record 43 of Set 5 | zhigansk
# Processing Record 44 of Set 5 | la ronge
# Processing Record 45 of Set 5 | faro
# Processing Record 46 of Set 5 | saint marys
# Processing Record 47 of Set 5 | vila franca do campo
# Processing Record 48 of Set 5 | buala
# Processing Record 49 of Set 5 | karratha
# Processing Record 50 of Set 5 | dudinka
# Processing Record 1 of Set 6 | seminole
# Processing Record 2 of Set 6 | ahipara
# Processing Record 3 of Set 6 | ende
# Processing Record 4 of Set 6 | newport
# Processing Record 5 of Set 6 | ostrovnoy
# Processing Record 6 of Set 6 | zhuanghe
# Processing Record 7 of Set 6 | sisimiut
# Processing Record 8 of Set 6 | emet
# Processing Record 9 of Set 6 | esperance
# Processing Record 10 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 11 of Set 6 | vallenar
# Processing Record 12 of Set 6 | hailar
# Processing Record 13 of Set 6 | valvedditturai
# Processing Record 14 of Set 6 | kloulklubed
# Processing Record 15 of Set 6 | palmer
# Processing Record 16 of Set 6 | cockburn town
# Processing Record 17 of Set 6 | berasia
# Processing Record 18 of Set 6 | kaeo
# Processing Record 19 of Set 6 | ilhabela
# Processing Record 20 of Set 6 | omboue
# Processing Record 21 of Set 6 | belaya gora
# Processing Record 22 of Set 6 | abnub
# Processing Record 23 of Set 6 | beroroha
# Processing Record 24 of Set 6 | kodiak
# Processing Record 25 of Set 6 | ambilobe
# Processing Record 26 of Set 6 | asyut
# Processing Record 27 of Set 6 | bossembele
# City not found. Skipping...
# Processing Record 28 of Set 6 | muyezerskiy
# Processing Record 29 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 30 of Set 6 | marsh harbour
# Processing Record 31 of Set 6 | cabo san lucas
# Processing Record 32 of Set 6 | lovozero
# Processing Record 33 of Set 6 | tuatapere
# Processing Record 34 of Set 6 | pauini
# Processing Record 35 of Set 6 | sirjan
# Processing Record 36 of Set 6 | lata
# Processing Record 37 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 6 | tairua
# Processing Record 39 of Set 6 | nabire
# Processing Record 40 of Set 6 | cap malheureux
# Processing Record 41 of Set 6 | hammerfest
# Processing Record 42 of Set 6 | malakal
# Processing Record 43 of Set 6 | chumikan
# Processing Record 44 of Set 6 | nikolskoye
# Processing Record 45 of Set 6 | kiama
# Processing Record 46 of Set 6 | nanyuki
# Processing Record 47 of Set 6 | bell ville
# Processing Record 48 of Set 6 | stabat
# Processing Record 49 of Set 6 | lompoc
# Processing Record 50 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 1 of Set 7 | neiafu
# Processing Record 2 of Set 7 | bakchar
# Processing Record 3 of Set 7 | pudozh
# Processing Record 4 of Set 7 | gossas
# Processing Record 5 of Set 7 | yellapur
# Processing Record 6 of Set 7 | flinders
# Processing Record 7 of Set 7 | akcaabat
# Processing Record 8 of Set 7 | myre
# Processing Record 9 of Set 7 | saint-joseph
# Processing Record 10 of Set 7 | zvishavane
# Processing Record 11 of Set 7 | margate
# Processing Record 12 of Set 7 | nola
# Processing Record 13 of Set 7 | bandarbeyla
# Processing Record 14 of Set 7 | oistins
# Processing Record 15 of Set 7 | vilanova del cami
# Processing Record 16 of Set 7 | kosh-agach
# Processing Record 17 of Set 7 | petatlan
# Processing Record 18 of Set 7 | kosa
# Processing Record 19 of Set 7 | sept-iles
# Processing Record 20 of Set 7 | khetia
# Processing Record 21 of Set 7 | providencia
# Processing Record 22 of Set 7 | phuthaditjhaba
# Processing Record 23 of Set 7 | lagoa
# Processing Record 24 of Set 7 | badarwas
# Processing Record 25 of Set 7 | rio grande
# Processing Record 26 of Set 7 | bonnyville
# Processing Record 27 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 28 of Set 7 | kilindoni
# Processing Record 29 of Set 7 | labuhan
# Processing Record 30 of Set 7 | pocatello
# Processing Record 31 of Set 7 | koupela
# Processing Record 32 of Set 7 | saldanha
# Processing Record 33 of Set 7 | seymchan
# Processing Record 34 of Set 7 | kuhdasht
# Processing Record 35 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 36 of Set 7 | chapais
# Processing Record 37 of Set 7 | los llanos de aridane
# Processing Record 38 of Set 7 | troitskoye
# Processing Record 39 of Set 7 | bentiu
# Processing Record 40 of Set 7 | meiringen
# Processing Record 41 of Set 7 | tuensang
# Processing Record 42 of Set 7 | coahuayana
# Processing Record 43 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 44 of Set 7 | trincomalee
# Processing Record 45 of Set 7 | montlucon
# Processing Record 46 of Set 7 | juiz de fora
# Processing Record 47 of Set 7 | nelson bay
# Processing Record 48 of Set 7 | poso
# Processing Record 49 of Set 7 | christchurch
# Processing Record 50 of Set 7 | port hardy
# Processing Record 1 of Set 8 | macaboboni
# City not found. Skipping...
# Processing Record 2 of Set 8 | komatipoort
# Processing Record 3 of Set 8 | goderich
# Processing Record 4 of Set 8 | zyryanka
# Processing Record 5 of Set 8 | mananjary
# Processing Record 6 of Set 8 | abu dhabi
# Processing Record 7 of Set 8 | athabasca
# Processing Record 8 of Set 8 | scalea
# Processing Record 9 of Set 8 | arzgir
# Processing Record 10 of Set 8 | vila
# Processing Record 11 of Set 8 | tura
# Processing Record 12 of Set 8 | merauke
# Processing Record 13 of Set 8 | khammam
# Processing Record 14 of Set 8 | asau
# Processing Record 15 of Set 8 | kaka
# Processing Record 16 of Set 8 | pangai
# Processing Record 17 of Set 8 | bereda
# Processing Record 18 of Set 8 | antalaha
# Processing Record 19 of Set 8 | midland
# Processing Record 20 of Set 8 | adre
# Processing Record 21 of Set 8 | roebourne
# Processing Record 22 of Set 8 | nata
# Processing Record 23 of Set 8 | torbay
# Processing Record 24 of Set 8 | agsu
# City not found. Skipping...
# Processing Record 25 of Set 8 | pouebo
# Processing Record 26 of Set 8 | arivonimamo
# Processing Record 27 of Set 8 | hasaki
# Processing Record 28 of Set 8 | green river
# Processing Record 29 of Set 8 | wladyslawowo
# Processing Record 30 of Set 8 | ulundi
# Processing Record 31 of Set 8 | ginir
# Processing Record 32 of Set 8 | same
# Processing Record 33 of Set 8 | bien hoa
# Processing Record 34 of Set 8 | carauari
# Processing Record 35 of Set 8 | dragotesti
# Processing Record 36 of Set 8 | sorland
# Processing Record 37 of Set 8 | hashtrud
# Processing Record 38 of Set 8 | puerto asis
# Processing Record 39 of Set 8 | gorom-gorom
# Processing Record 40 of Set 8 | quatre cocos
# Processing Record 41 of Set 8 | belyy yar
# Processing Record 42 of Set 8 | atbasar
# Processing Record 43 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 45 of Set 8 | elliot
# Processing Record 46 of Set 8 | barabai
# Processing Record 47 of Set 8 | cayenne
# Processing Record 48 of Set 8 | jalu
# Processing Record 49 of Set 8 | chernyshkovskiy
# Processing Record 50 of Set 8 | dubbo
# Processing Record 1 of Set 9 | onzaga
# Processing Record 2 of Set 9 | kudahuvadhoo
# Processing Record 3 of Set 9 | miyako
# Processing Record 4 of Set 9 | hambantota
# Processing Record 5 of Set 9 | jumla
# Processing Record 6 of Set 9 | cascais
# Processing Record 7 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 9 | mount gambier
# Processing Record 9 of Set 9 | mandera
# Processing Record 10 of Set 9 | genhe
# Processing Record 11 of Set 9 | kirensk
# Processing Record 12 of Set 9 | moerai
# Processing Record 13 of Set 9 | kerki
# City not found. Skipping...
# Processing Record 14 of Set 9 | miri
# Processing Record 15 of Set 9 | dumai
# Processing Record 16 of Set 9 | mattawa
# Processing Record 17 of Set 9 | balashov
# Processing Record 18 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 9 | albi
# Processing Record 20 of Set 9 | pacific grove
# Processing Record 21 of Set 9 | vardo
# Processing Record 22 of Set 9 | ibra
# Processing Record 23 of Set 9 | gejiu
# Processing Record 24 of Set 9 | ballina
# Processing Record 25 of Set 9 | hovd
# Processing Record 26 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 27 of Set 9 | turan
# Processing Record 28 of Set 9 | aonla
# Processing Record 29 of Set 9 | biak
# Processing Record 30 of Set 9 | noumea
# Processing Record 31 of Set 9 | varna
# Processing Record 32 of Set 9 | yatou
# Processing Record 33 of Set 9 | potiskum
# Processing Record 34 of Set 9 | lewisporte
# Processing Record 35 of Set 9 | tazovskiy
# Processing Record 36 of Set 9 | rawson
# Processing Record 37 of Set 9 | tarakan
# Processing Record 38 of Set 9 | rio gallegos
# Processing Record 39 of Set 9 | port macquarie
# Processing Record 40 of Set 9 | nizhnedevitsk
# Processing Record 41 of Set 9 | kawalu
# Processing Record 42 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 43 of Set 9 | usinsk
# Processing Record 44 of Set 9 | palmeiras de goias
# Processing Record 45 of Set 9 | general pico
# Processing Record 46 of Set 9 | rantepao
# Processing Record 47 of Set 9 | bilibino
# Processing Record 48 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 49 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 50 of Set 9 | grindavik
# Processing Record 1 of Set 10 | nyurba
# Processing Record 2 of Set 10 | faya
# Processing Record 3 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 10 | ulaangom
# Processing Record 5 of Set 10 | mackay
# Processing Record 6 of Set 10 | alihe
# Processing Record 7 of Set 10 | san patricio
# Processing Record 8 of Set 10 | state college
# Processing Record 9 of Set 10 | oleksandrivka
# Processing Record 10 of Set 10 | general roca
# Processing Record 11 of Set 10 | micheweni
# Processing Record 12 of Set 10 | solnechnyy
# Processing Record 13 of Set 10 | celestun
# Processing Record 14 of Set 10 | bandar-e lengeh
# Processing Record 15 of Set 10 | severodvinsk
# Processing Record 16 of Set 10 | elat
# Processing Record 17 of Set 10 | necochea
# Processing Record 18 of Set 10 | pokaran
# Processing Record 19 of Set 10 | ukiah
# Processing Record 20 of Set 10 | bemidji
# Processing Record 21 of Set 10 | raga
# Processing Record 22 of Set 10 | sovetskiy
# Processing Record 23 of Set 10 | puri
# Processing Record 24 of Set 10 | huai thalaeng
# Processing Record 25 of Set 10 | stornoway
# Processing Record 26 of Set 10 | surovikino
# Processing Record 27 of Set 10 | longyearbyen
# Processing Record 28 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 10 | key west
# Processing Record 30 of Set 10 | praia
# Processing Record 31 of Set 10 | meulaboh
# Processing Record 32 of Set 10 | copala
# Processing Record 33 of Set 10 | manresa
# Processing Record 34 of Set 10 | aitape
# Processing Record 35 of Set 10 | zhangye
# Processing Record 36 of Set 10 | muros
# Processing Record 37 of Set 10 | kurilsk
# Processing Record 38 of Set 10 | fairbanks
# Processing Record 39 of Set 10 | alzamay
# Processing Record 40 of Set 10 | jadu
# Processing Record 41 of Set 10 | beringovskiy
# Processing Record 42 of Set 10 | maple creek
# Processing Record 43 of Set 10 | faanui
# Processing Record 44 of Set 10 | powell river
# Processing Record 45 of Set 10 | bertoua
# Processing Record 46 of Set 10 | corrales
# Processing Record 47 of Set 10 | aripuana
# Processing Record 48 of Set 10 | mwanza
# Processing Record 49 of Set 10 | chicama
# Processing Record 50 of Set 10 | kahului
# Processing Record 1 of Set 11 | naples
# Processing Record 2 of Set 11 | hvide sande
# Processing Record 3 of Set 11 | zonguldak
# Processing Record 4 of Set 11 | tuyen quang
# Processing Record 5 of Set 11 | caraballeda
# Processing Record 6 of Set 11 | pringsewu
# Processing Record 7 of Set 11 | marzuq
# Processing Record 8 of Set 11 | erenhot
# Processing Record 9 of Set 11 | bogale
# Processing Record 10 of Set 11 | nantucket
# Processing Record 11 of Set 11 | panaba
# Processing Record 12 of Set 11 | lavrentiya
# Processing Record 13 of Set 11 | vezirkopru
# Processing Record 14 of Set 11 | uige
# Processing Record 15 of Set 11 | angoche
# Processing Record 16 of Set 11 | leh
# Processing Record 17 of Set 11 | show low
# Processing Record 18 of Set 11 | kedrovyy
# Processing Record 19 of Set 11 | la palma
# Processing Record 20 of Set 11 | baghdad
# Processing Record 21 of Set 11 | chaa-khol
# City not found. Skipping...
# Processing Record 22 of Set 11 | paranaiba
# Processing Record 23 of Set 11 | rocha
# Processing Record 24 of Set 11 | marsa matruh
# Processing Record 25 of Set 11 | lorengau
# Processing Record 26 of Set 11 | tocopilla
# Processing Record 27 of Set 11 | alofi
# Processing Record 28 of Set 11 | praia da vitoria
# Processing Record 29 of Set 11 | burns lake
# Processing Record 30 of Set 11 | provideniya
# Processing Record 31 of Set 11 | beni suef
# Processing Record 32 of Set 11 | damaturu
# Processing Record 33 of Set 11 | tiksi
# Processing Record 34 of Set 11 | mangai
# Processing Record 35 of Set 11 | cacoal
# Processing Record 36 of Set 11 | hofn
# Processing Record 37 of Set 11 | tessalit
# Processing Record 38 of Set 11 | aswan
# Processing Record 39 of Set 11 | pierre
# Processing Record 40 of Set 11 | brae
# Processing Record 41 of Set 11 | oktyabrskoye
# Processing Record 42 of Set 11 | aden
# Processing Record 43 of Set 11 | raudeberg
# Processing Record 44 of Set 11 | waingapu
# Processing Record 45 of Set 11 | oranjemund
# Processing Record 46 of Set 11 | loiza
# Processing Record 47 of Set 11 | burkhala
# City not found. Skipping...
# Processing Record 48 of Set 11 | the valley
# Processing Record 49 of Set 11 | shchebetovka
# Processing Record 50 of Set 11 | lerwick
# Processing Record 1 of Set 12 | boddam
# Processing Record 2 of Set 12 | linxia
# Processing Record 3 of Set 12 | sencur
# Processing Record 4 of Set 12 | kraslava
# Processing Record 5 of Set 12 | yambio
# Processing Record 6 of Set 12 | cortez
# Processing Record 7 of Set 12 | mecca
# Processing Record 8 of Set 12 | yumen
# Processing Record 9 of Set 12 | iki-burul
# Processing Record 10 of Set 12 | coro
# Processing Record 11 of Set 12 | placido de castro
# Processing Record 12 of Set 12 | kiruna
# Processing Record 13 of Set 12 | santa fe
# Processing Record 14 of Set 12 | richard toll
# City not found. Skipping...
# Processing Record 15 of Set 12 | nizwa
# Processing Record 16 of Set 12 | amazar
# Processing Record 17 of Set 12 | dhidhdhoo
# Processing Record 18 of Set 12 | bagdarin
# Processing Record 19 of Set 12 | kanniyakumari
# Processing Record 20 of Set 12 | deputatskiy
# Processing Record 21 of Set 12 | thilogne
# City not found. Skipping...
# Processing Record 22 of Set 12 | troitsko-pechorsk
# Processing Record 23 of Set 12 | rognan
# Processing Record 24 of Set 12 | riyadh
# Processing Record 25 of Set 12 | kondinskoye
# Processing Record 26 of Set 12 | puerto carreno
# Processing Record 27 of Set 12 | abu samrah
# Processing Record 28 of Set 12 | mound
# Processing Record 29 of Set 12 | zavitinsk
# Processing Record 30 of Set 12 | qui nhon
# Processing Record 31 of Set 12 | smithers
# Processing Record 32 of Set 12 | maneadero
# Processing Record 33 of Set 12 | preeceville
# Processing Record 34 of Set 12 | roald
# Processing Record 35 of Set 12 | yulara
# Processing Record 36 of Set 12 | srednekolymsk
# Processing Record 37 of Set 12 | teya
# Processing Record 38 of Set 12 | itarema
# Processing Record 39 of Set 12 | tianmen
# Processing Record 40 of Set 12 | dien bien
# City not found. Skipping...
# Processing Record 41 of Set 12 | beloha
# Processing Record 42 of Set 12 | zhezkazgan
# Processing Record 43 of Set 12 | tabuk
# Processing Record 44 of Set 12 | mitu
# Processing Record 45 of Set 12 | fortuna
# Processing Record 46 of Set 12 | jacareacanga
# Processing Record 47 of Set 12 | wairoa
# Processing Record 48 of Set 12 | george
# Processing Record 49 of Set 12 | saint-pierre
# Processing Record 50 of Set 12 | port-de-paix
# City not found. Skipping...
# Processing Record 1 of Set 13 | tam ky
# Processing Record 2 of Set 13 | svetlogorsk
# Processing Record 3 of Set 13 | rincon
# Processing Record 4 of Set 13 | owensboro
# Processing Record 5 of Set 13 | tabarqah
# City not found. Skipping...
# Processing Record 6 of Set 13 | elk point
# Processing Record 7 of Set 13 | matara
# Processing Record 8 of Set 13 | boende
# Processing Record 9 of Set 13 | matucana
# Processing Record 10 of Set 13 | ericeira
# Processing Record 11 of Set 13 | ilulissat
# Processing Record 12 of Set 13 | ca mau
# Processing Record 13 of Set 13 | omsukchan
# Processing Record 14 of Set 13 | china
# Processing Record 15 of Set 13 | waipawa
# Processing Record 16 of Set 13 | villefranche-de-rouergue
# Processing Record 17 of Set 13 | carbonia
# Processing Record 18 of Set 13 | mpophomeni
# Processing Record 19 of Set 13 | aguimes
# Processing Record 20 of Set 13 | macau
# Processing Record 21 of Set 13 | ongandjera
# Processing Record 22 of Set 13 | estevan
# Processing Record 23 of Set 13 | san cristobal
# Processing Record 24 of Set 13 | puerto escondido
# Processing Record 25 of Set 13 | botwood
# Processing Record 26 of Set 13 | nagato
# Processing Record 27 of Set 13 | kimbe
# Processing Record 28 of Set 13 | denau
# City not found. Skipping...
# Processing Record 29 of Set 13 | mitsamiouli
# Processing Record 30 of Set 13 | kenora
# Processing Record 31 of Set 13 | bengkalis
# City not found. Skipping...
# Processing Record 32 of Set 13 | zhangjiakou
# Processing Record 33 of Set 13 | ardakan
# Processing Record 34 of Set 13 | miles city
# Processing Record 35 of Set 13 | sao mateus
# Processing Record 36 of Set 13 | andros town
# Processing Record 37 of Set 13 | vypolzovo
# Processing Record 38 of Set 13 | lhokseumawe
# Processing Record 39 of Set 13 | santa maria da boa vista
# Processing Record 40 of Set 13 | auki
# Processing Record 41 of Set 13 | juneau
# Processing Record 42 of Set 13 | wilmington
# Processing Record 43 of Set 13 | imbituba
# Processing Record 44 of Set 13 | yaan
# Processing Record 45 of Set 13 | portsmouth
# Processing Record 46 of Set 13 | coquimbo
# Processing Record 47 of Set 13 | battle creek
# Processing Record 48 of Set 13 | tateyama
# Processing Record 49 of Set 13 | shibetsu
# Processing Record 50 of Set 13 | rio branco do sul
# Processing Record 1 of Set 14 | taoudenni
# Processing Record 2 of Set 14 | barroualie
# City not found. Skipping...
# Processing Record 3 of Set 14 | clyde river
# Processing Record 4 of Set 14 | qinhuangdao
# Processing Record 5 of Set 14 | wagar
# Processing Record 6 of Set 14 | san juan
# Processing Record 7 of Set 14 | nago
# Processing Record 8 of Set 14 | salinopolis
# Processing Record 9 of Set 14 | albury
# Processing Record 10 of Set 14 | qasigiannguit
# Processing Record 11 of Set 14 | bara
# Processing Record 12 of Set 14 | chepareria
# Processing Record 13 of Set 14 | poum
# Processing Record 14 of Set 14 | puerto madero
# Processing Record 15 of Set 14 | verkhnevilyuysk
# Processing Record 16 of Set 14 | conakry
# Processing Record 17 of Set 14 | hualmay
# Processing Record 18 of Set 14 | cordoba
# Processing Record 19 of Set 14 | sindon
# Processing Record 20 of Set 14 | gela
# Processing Record 21 of Set 14 | liverpool
# Processing Record 22 of Set 14 | bonfim
# Processing Record 23 of Set 14 | iguatu
# Processing Record 24 of Set 14 | kankakee
# Processing Record 25 of Set 14 | kapoeta
# Processing Record 26 of Set 14 | muhos
# Processing Record 27 of Set 14 | maniitsoq
# Processing Record 28 of Set 14 | aykhal
# Processing Record 29 of Set 14 | ixtapa
# Processing Record 30 of Set 14 | fuerte
# Processing Record 31 of Set 14 | sidvokodvo
# Processing Record 32 of Set 14 | ancud
# Processing Record 33 of Set 14 | puerto el triunfo
# Processing Record 34 of Set 14 | tongliao
# Processing Record 35 of Set 14 | shrewsbury
# Processing Record 36 of Set 14 | gizo
# Processing Record 37 of Set 14 | lasa
# Processing Record 38 of Set 14 | porkhov
# Processing Record 39 of Set 14 | havelock
# Processing Record 40 of Set 14 | kijang
# Processing Record 41 of Set 14 | boulsa
# Processing Record 42 of Set 14 | tulu bolo
# Processing Record 43 of Set 14 | santiago
# Processing Record 44 of Set 14 | saskylakh
# Processing Record 45 of Set 14 | yandyki
# Processing Record 46 of Set 14 | southbridge
# Processing Record 47 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 48 of Set 14 | bilma
# Processing Record 49 of Set 14 | mocuba
# Processing Record 50 of Set 14 | ravar
# Processing Record 1 of Set 15 | gao
# Processing Record 2 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 3 of Set 15 | halifax
# Processing Record 4 of Set 15 | kolno
# Processing Record 5 of Set 15 | sysert
# Processing Record 6 of Set 15 | kotelnich
# Processing Record 7 of Set 15 | san juan del sur
# Processing Record 8 of Set 15 | mangaratiba
# Processing Record 9 of Set 15 | mersing
# Processing Record 10 of Set 15 | abha
# Processing Record 11 of Set 15 | shingu
# Processing Record 12 of Set 15 | schattdorf
# Processing Record 13 of Set 15 | kharp
# Processing Record 14 of Set 15 | katobu
# Processing Record 15 of Set 15 | mackenzie
# Processing Record 16 of Set 15 | alyangula
# Processing Record 17 of Set 15 | merisani
# Processing Record 18 of Set 15 | ponta delgada
# Processing Record 19 of Set 15 | sarangani
# Processing Record 20 of Set 15 | vredendal
# Processing Record 21 of Set 15 | barra do corda
# Processing Record 22 of Set 15 | santa maria
# Processing Record 23 of Set 15 | khormuj
# City not found. Skipping...
# Processing Record 24 of Set 15 | comodoro rivadavia
# Processing Record 25 of Set 15 | seoul
# Processing Record 26 of Set 15 | nueva loja
# Processing Record 27 of Set 15 | zeya
# Processing Record 28 of Set 15 | port moresby
# Processing Record 29 of Set 15 | banamba
# Processing Record 30 of Set 15 | kupang
# Processing Record 31 of Set 15 | egvekinot
# Processing Record 32 of Set 15 | price
# Processing Record 33 of Set 15 | kitangari
# Processing Record 34 of Set 15 | mantua
# Processing Record 35 of Set 15 | wanning
# Processing Record 36 of Set 15 | sarakhs
# Processing Record 37 of Set 15 | russell
# Processing Record 38 of Set 15 | port shepstone
# Processing Record 39 of Set 15 | horsham
# Processing Record 40 of Set 15 | sorkjosen
# Processing Record 41 of Set 15 | tomatlan
# Processing Record 42 of Set 15 | byron bay
# Processing Record 43 of Set 15 | pimentel
# Processing Record 44 of Set 15 | koutsouras
# Processing Record 45 of Set 15 | kruisfontein
# Processing Record 46 of Set 15 | edea
# Processing Record 47 of Set 15 | banjarmasin
# Processing Record 48 of Set 15 | grand centre
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  San Quintin      MX  30.4833 -115.9500     55.99        82          13
# 1      Mareeba      AU -17.0000  145.4333     79.52        75          48
# 2      Mataura      NZ -46.1927  168.8643     57.47        89          25
# 3    Ostersund      SE  63.1792   14.6357     30.65        80           0
# 4      Ushuaia      AR -54.8000  -68.3000     37.06        81         100
# 5     Tasiilaq      GL  65.6145  -37.6368     21.56        94         100
# 6       Dikson      RU  73.5069   80.5464     14.34        88          40
# 7      Rikitea      PF -23.1203 -134.9692     77.76        80          95
# 8       Hohhot      CN  40.8106  111.6522     80.89        13           0
# 9       Atuona      PF  -9.8000 -139.0333     79.36        77         100
#
#    Wind Speed Current Description
# 0        4.76          few clouds
# 1        4.90    scattered clouds
# 2        1.10    scattered clouds
# 3        3.44           clear sky
# 4       19.57          light rain
# 5        6.76          light snow
# 6        6.55    scattered clouds
# 7       18.45     overcast clouds
# 8       13.42           clear sky
# 9       18.99     overcast clouds

# %%
# Export data frame as CSV
output_data_file = 'WeatherPy_Database.csv'
city_data_df.to_csv(output_data_file,index_label='City_ID')
